# %%
import tensorflow as tf
import tensorflow.keras.datasets.cifar10
import keras
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split


from tensorflow.keras.models import Sequential 

from tensorflow.keras.layers import Conv2D 
from tensorflow.keras.layers import MaxPooling2D 
from tensorflow.keras.layers import Flatten 
from tensorflow.keras.layers import Dense
import cv2
# Out:
# C:\Users\Yigit\miniconda3\lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.15) or chardet (5.1.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
# VERİ SETİMİZİ ÇEKTİK

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# %%
plt.imshow(x_test[1])

# %%
for i in range(5):
    plt.imshow(x_test[1])
    plt.title("Sınıf: "+ str(y_test[i][0]))
    plt.show()

# %%
# X VE Y VERİLERİMİZİ BİRLEŞTİRDİK

# %%
x_data = np.concatenate((x_train , x_test) , axis=0)
y_data = np.concatenate((y_train , y_test) , axis=0)

# %%
#  TEST VE EĞİTİM OLARAK BÖLDÜK

# %%
x_train , x_test , y_train , y_test = train_test_split(x_data , y_data , test_size=0.2 , random_state=42)

# %%
# RESİM DEĞERLERİMİZİN RENK TONU 0-255 ARASINDA OLDUĞU İÇİN NORMALİZE EDERKEN RENKLERİMİZİ 255 E BÖLDÜK

# %%
x_train = x_train.astype('float32')/255.0
x_test = x_test.astype('float32')/255.0

# %%
# ETİKET VERİLERİMİZİ SINIF SAYIMIZI VEREREK KATEGORİZE ETTİK

# %%
num_classes = 10
y_train = keras.utils.to_categorical(y_train , num_classes)
y_test = keras.utils.to_categorical(y_test , num_classes)

# %%
# GEREKLİ FİLTRELERİ UYGULADIK , MODELİMİZİ DERİN ÖĞRENME ALGORİTMASINDAN GEÇİRDİK

# %%
model = Sequential()

model.add(Conv2D(32,(3,3) , activation="relu" , padding="same" , input_shape=x_train.shape[1:]))


model.add(Conv2D(32,(3,3) , activation="relu"))


model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,(3,3) , activation="relu" , padding="same"))
model.add(Conv2D(64,(3,3) , activation="relu"))


model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Flatten())
model.add(Dense(512,activation="relu"))

model.add(Dense(num_classes , activation="softmax"))

# %%
model.compile(loss="categorical_crossentropy" , optimizer="adam" , metrics=["accuracy"])

# %%
# DERİN ÖĞRENMEDE İŞLEDİĞİMİZ VERİLERİN ÖZETİNİ ÇIKARDIK

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
# MODELİMİZİ FİT ETTİK

# %%
batch_size = 128
epochs= 30
model.fit(x_train , y_train , batch_size=batch_size , epochs=epochs , validation_data = (x_test,y_test))
# Out:
# Epoch 1/30
# 375/375 [==============================] - 115s 299ms/step - loss: 1.5179 - accuracy: 0.4459 - val_loss: 1.2560 - val_accuracy: 0.5479
# Epoch 2/30
# 375/375 [==============================] - 91s 243ms/step - loss: 1.0920 - accuracy: 0.6143 - val_loss: 1.0180 - val_accuracy: 0.6415
# Epoch 3/30
# 375/375 [==============================] - 91s 244ms/step - loss: 0.8927 - accuracy: 0.6883 - val_loss: 0.9020 - val_accuracy: 0.6838
# Epoch 4/30
# 375/375 [==============================] - 86s 230ms/step - loss: 0.7725 - accuracy: 0.7305 - val_loss: 0.8529 - val_accuracy: 0.6987
# Epoch 5/30
# 375/375 [==============================] - 85s 226ms/step - loss: 0.6677 - accuracy: 0.7681 - val_loss: 0.7642 - val_accuracy: 0.7351
# Epoch 6/30
# 375/375 [==============================] - 85s 226ms/step - loss: 0.5647 - accuracy: 0.8025 - val_loss: 0.8029 - val_accuracy: 0.7323
# Epoch 7/30
# 375/375 [==============================] - 86s 229ms/step - loss: 0.4703 - accuracy: 0.8346 - val_loss: 0.8220 - val_accuracy: 0.7385
# Epoch 8/30
# 375/375 [==============================] - 98s 262ms/step - loss: 0.3760 - accuracy: 0.8681 - val_loss: 0.8022 - val_accuracy: 0.7440
# Epoch 9/30
# 375/375 [==============================] - 95s 254ms/step - loss: 0.2913 - accuracy: 0.8980 - val_loss: 0.9326 - val_accuracy: 0.7290
# Epoch 10/30
# 375/375 [==============================] - 96s 255ms/step - loss: 0.2216 - accuracy: 0.9236 - val_loss: 1.0561 - val_accuracy: 0.7394
# Epoch 11/30
# 375/375 [==============================] - 97s 260ms/step - loss: 0.1600 - accuracy: 0.9448 - val_loss: 1.1556 - val_accuracy: 0.7332
# Epoch 12/30
# 375/375 [==============================] - 98s 263ms/step - loss: 0.1255 - accuracy: 0.9563 - val_loss: 1.2037 - val_accuracy: 0.7410
# Epoch 13/30
# 375/375 [==============================] - 100s 266ms/step - loss: 0.0981 - accuracy: 0.9660 - val_loss: 1.3308 - val_accuracy: 0.7368
# Epoch 14/30
# 375/375 [==============================] - 86s 228ms/step - loss: 0.0766 - accuracy: 0.9733 - val_loss: 1.4483 - val_accuracy: 0.7406
# Epoch 15/30
# 375/375 [==============================] - 85s 227ms/step - loss: 0.0769 - accuracy: 0.9729 - val_loss: 1.5617 - val_accuracy: 0.7401
# Epoch 16/30
# 375/375 [==============================] - 86s 229ms/step - loss: 0.0747 - accuracy: 0.9744 - val_loss: 1.4807 - val_accuracy: 0.7361
# Epoch 17/30
# 375/375 [==============================] - 85s 227ms/step - loss: 0.0656 - accuracy: 0.9780 - val_loss: 1.6520 - val_accuracy: 0.7240
# Epoch 18/30
# 375/375 [==============================] - 85s 227ms/step - loss: 0.0627 - accuracy: 0.9779 - val_loss: 1.6470 - val_accuracy: 0.7336
# Epoch 19/30
# 375/375 [==============================] - 85s 227ms/step - loss: 0.0524 - accuracy: 0.9820 - val_loss: 1.6921 - val_accuracy: 0.7463
# Epoch 20/30
# 375/375 [==============================] - 84s 225ms/step - loss: 0.0519 - accuracy: 0.9822 - val_loss: 1.8396 - val_accuracy: 0.7351
# Epoch 21/30
# 375/375 [==============================] - 84s 224ms/step - loss: 0.0505 - accuracy: 0.9822 - val_loss: 1.9099 - val_accuracy: 0.7379
# Epoch 22/30
# 375/375 [==============================] - 84s 223ms/step - loss: 0.0575 - accuracy: 0.9808 - val_loss: 1.8917 - val_accuracy: 0.7358
# Epoch 23/30
# 375/375 [==============================] - 84s 223ms/step - loss: 0.0477 - accuracy: 0.9835 - val_loss: 1.9423 - val_accuracy: 0.7333
# Epoch 24/30
# 375/375 [==============================] - 83s 223ms/step - loss: 0.0481 - accuracy: 0.9836 - val_loss: 1.9365 - val_accuracy: 0.7389
# Epoch 25/30
# 375/375 [==============================] - 83s 222ms/step - loss: 0.0399 - accuracy: 0.9865 - val_loss: 1.9384 - val_accuracy: 0.7380
# Epoch 26/30
# 375/375 [==============================] - 83s 222ms/step - loss: 0.0436 - accuracy: 0.9851 - val_loss: 1.9966 - val_accuracy: 0.7285
# Epoch 27/30
# 375/375 [==============================] - 84s 223ms/step - loss: 0.0537 - accuracy: 0.9823 - val_loss: 1.9606 - val_accuracy: 0.7343
# Epoch 28/30
# 375/375 [==============================] - 100s 266ms/step - loss: 0.0385 - accuracy: 0.9874 - val_loss: 2.0781 - val_accuracy: 0.7303
# Epoch 29/30
# 375/375 [==============================] - 119s 317ms/step - loss: 0.0434 - accuracy: 0.9852 - val_loss: 2.1142 - val_accuracy: 0.7347
# Epoch 30/30
# 375/375 [==============================] - 113s 302ms/step - loss: 0.0453 - accuracy: 0.9855 - val_loss: 2.0237 - val_accuracy: 0.7318

# %%
scores = model.evaluate(x_test,y_test, verbose=1)
print("test loss: " , scores[0])
print("test accuracy: " , scores[1])
# Out:
# 375/375 [==============================] - 4s 11ms/step - loss: 2.0237 - accuracy: 0.7318
# test loss:  2.023684501647949
# test accuracy:  0.7317500114440918
